# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Data_Sets/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Data_Sets/'
# /content/drive/MyDrive/Data_Sets

# %%
import os

# %%
os.listdir()
# Out:
# ['acc_walking_data_2',
#  'acc_walking_data_6',
#  'acc_walking_data_14',
#  'acc_walking_data_8',
#  'acc_walking_data_3',
#  'acc_walking_data_7',
#  'acc_walking_data_5',
#  'acc_walking_data_4',
#  'acc_walking_data_15',
#  'acc_walking_data_9',
#  'acc_walking_data_10',
#  'acc_running_data_5',
#  'acc_walking_data_1',
#  'acc_walking_data_11',
#  'acc_running_data_9',
#  'acc_running_data_8',
#  'acc_running_data_7',
#  'acc_walking_data_12',
#  'acc_walking_data_13',
#  'acc_running_data_6',
#  'acc_running_data_11',
#  'acc_running_data_13',
#  'acc_running_data_12',
#  'acc_running_data_10',
#  'acc_running_data_3',
#  'acc_running_data_1',
#  'acc_running_data_2',
#  'acc_running_data_14',
#  'acc_running_data_15',
#  'acc_running_data_4',
#  'acc_climbingup_data_8',
#  'acc_climbingup_data_4',
#  'acc_climbingup_data_5',
#  'acc_climbingup_data_2',
#  'acc_climbingup_data_3',
#  'acc_climbingup_data_14',
#  'acc_climbingup_data_7',
#  'acc_climbingup_data_6',
#  'acc_climbingup_data_15',
#  'acc_climbingup_data_9',
#  'acc_climbingdown_data_9',
#  'acc_climbingup_data_10',
#  'acc_climbingdown_data_7',
#  'acc_climbingup_data_1',
#  'acc_climbingdown_data_6',
#  'acc_climbingup_data_11',
#  'acc_climbingup_data_12',
#  'acc_climbingup_data_13',
#  'acc_climbingdown_data_8',
#  'acc_climbingdown_data_5',
#  'acc_climbingdown_data_14',
#  'acc_climbingdown_data_1',
#  'acc_climbingdown_data_3',
#  'acc_climbingdown_data_10',
#  'acc_climbingdown_data_4',
#  'acc_climbingdown_data_13',
#  'acc_climbingdown_data_11',
#  'acc_climbingdown_data_12',
#  'acc_climbingdown_data_15',
#  'acc_climbingdown_data_2']

# %%
# !pip install ts2vg cairocffi igraph
# !pip install pycairo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ts2vg in /usr/local/lib/python3.8/dist-packages (1.0.0)
# Requirement already satisfied: cairocffi in /usr/local/lib/python3.8/dist-packages (1.4.0)
# Requirement already satisfied: igraph in /usr/local/lib/python3.8/dist-packages (0.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ts2vg) (1.21.6)
# Requirement already satisfied: cffi>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from cairocffi) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.1.0->cairocffi) (2.21)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.8/dist-packages (from igraph) (1.6.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycairo
#   Using cached pycairo-1.23.0.tar.gz (344 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pycairo
#   Building wheel for pycairo (PEP 517) ... error
#   ERROR: Failed building wheel for pycairo
# Failed to build pycairo
# ERROR: Could not build wheels for pycairo which use PEP 517 and cannot be installed directly

# %%
from ts2vg import NaturalVG, HorizontalVG
import numpy as np
import igraph
import cairocffi
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col = ["Method", "Subject", "Accelerometer Axis", "Average Degree",
            "Network Diameter", "Average Path Length", "Activity","Sensor"]
final_table = pd.DataFrame(columns = col)
activities = ["walking", "running", "climbingup", "climbingdown"]
subjects = list(range(1, 16))
axis = list("xyz")
sensors = ["chest", "forearm", "head", "shin", "thigh", "upperarm", "waist"]
methods = [NaturalVG, HorizontalVG]

# %%
for subject in subjects:
  for activity in activities:
    for sensor in sensors:
      try:
       foldername = "acc_"+activity+"_data_"+str(subject)
       filename = "acc_"+activity+"_"+sensor+".csv"
       print(foldername,'-',sensor)
       task_1 = pd.read_csv(foldername+"/"+filename)
       for method in methods:
         for ax in axis:            
             g = method()
             g.build(task_1["attr_"+ax][1000:2024])
             ig = g.as_igraph()
             result = [method.__name__, subject, ax.upper(), np.mean(ig.degree()), 
                     ig.diameter(), ig.average_path_length(), activity,sensor]
             new_d = dict(zip(col, result))
             final_table = final_table.append(new_d, ignore_index=True)
      except Exception:
          continue
# Out:
# acc_walking_data_1 - chest
# acc_walking_data_1 - forearm
# acc_walking_data_1 - head
# acc_walking_data_1 - shin
# acc_walking_data_1 - thigh
# acc_walking_data_1 - upperarm
# acc_walking_data_1 - waist
# acc_running_data_1 - chest
# acc_running_data_1 - forearm
# acc_running_data_1 - head
# acc_running_data_1 - shin
# acc_running_data_1 - thigh
# acc_running_data_1 - upperarm
# acc_running_data_1 - waist
# acc_climbingup_data_1 - chest
# acc_climbingup_data_1 - forearm
# acc_climbingup_data_1 - head
# acc_climbingup_data_1 - shin
# acc_climbingup_data_1 - thigh
# acc_climbingup_data_1 - upperarm
# acc_climbingup_data_1 - waist
# acc_climbingdown_data_1 - chest
# acc_climbingdown_data_1 - forearm
# acc_climbingdown_data_1 - head
# acc_climbingdown_data_1 - shin
# acc_climbingdown_data_1 - thigh
# acc_climbingdown_data_1 - upperarm
# acc_climbingdown_data_1 - waist
# acc_walking_data_2 - chest
# acc_walking_data_2 - forearm
# acc_walking_data_2 - head
# acc_walking_data_2 - shin
# acc_walking_data_2 - thigh
# acc_walking_data_2 - upperarm
# acc_walking_data_2 - waist
# acc_running_data_2 - chest
# acc_running_data_2 - forearm
# acc_running_data_2 - head
# acc_running_data_2 - shin
# acc_running_data_2 - thigh
# acc_running_data_2 - upperarm
# acc_running_data_2 - waist
# acc_climbingup_data_2 - chest
# acc_climbingup_data_2 - forearm
# acc_climbingup_data_2 - head
# acc_climbingup_data_2 - shin
# acc_climbingup_data_2 - thigh
# acc_climbingup_data_2 - upperarm
# acc_climbingup_data_2 - waist
# acc_climbingdown_data_2 - chest
# acc_climbingdown_data_2 - forearm
# acc_climbingdown_data_2 - head
# acc_climbingdown_data_2 - shin
# acc_climbingdown_data_2 - thigh
# acc_climbingdown_data_2 - upperarm
# acc_climbingdown_data_2 - waist
# acc_walking_data_3 - chest
# acc_walking_data_3 - forearm
# acc_walking_data_3 - head
# acc_walking_data_3 - shin
# acc_walking_data_3 - thigh
# acc_walking_data_3 - upperarm
# acc_walking_data_3 - waist
# acc_running_data_3 - chest
# acc_running_data_3 - forearm
# acc_running_data_3 - head
# acc_running_data_3 - shin
# acc_running_data_3 - thigh
# acc_running_data_3 - upperarm
# acc_running_data_3 - waist
# acc_climbingup_data_3 - chest
# acc_climbingup_data_3 - forearm
# acc_climbingup_data_3 - head
# acc_climbingup_data_3 - shin
# acc_climbingup_data_3 - thigh
# acc_climbingup_data_3 - upperarm
# acc_climbingup_data_3 - waist
# acc_climbingdown_data_3 - chest
# acc_climbingdown_data_3 - forearm
# acc_climbingdown_data_3 - head
# acc_climbingdown_data_3 - shin
# acc_climbingdown_data_3 - thigh
# acc_climbingdown_data_3 - upperarm
# acc_climbingdown_data_3 - waist
# acc_walking_data_4 - chest
# acc_walking_data_4 - forearm
# acc_walking_data_4 - head
# acc_walking_data_4 - shin
# acc_walking_data_4 - thigh
# acc_walking_data_4 - upperarm
# acc_walking_data_4 - waist
# acc_running_data_4 - chest
# acc_running_data_4 - forearm
# acc_running_data_4 - head
# acc_running_data_4 - shin
# acc_running_data_4 - thigh
# acc_running_data_4 - upperarm
# acc_running_data_4 - waist
# acc_climbingup_data_4 - chest
# acc_climbingup_data_4 - forearm
# acc_climbingup_data_4 - head
# acc_climbingup_data_4 - shin
# acc_climbingup_data_4 - thigh
# acc_climbingup_data_4 - upperarm
# acc_climbingup_data_4 - waist
# acc_climbingdown_data_4 - chest
# acc_climbingdown_data_4 - forearm
# acc_climbingdown_data_4 - head
# acc_climbingdown_data_4 - shin
# acc_climbingdown_data_4 - thigh
# acc_climbingdown_data_4 - upperarm
# acc_climbingdown_data_4 - waist
# acc_walking_data_5 - chest
# acc_walking_data_5 - forearm
# acc_walking_data_5 - head
# acc_walking_data_5 - shin
# acc_walking_data_5 - thigh
# acc_walking_data_5 - upperarm
# acc_walking_data_5 - waist
# acc_running_data_5 - chest
# acc_running_data_5 - forearm
# acc_running_data_5 - head
# acc_running_data_5 - shin
# acc_running_data_5 - thigh
# acc_running_data_5 - upperarm
# acc_running_data_5 - waist
# acc_climbingup_data_5 - chest
# acc_climbingup_data_5 - forearm
# acc_climbingup_data_5 - head
# acc_climbingup_data_5 - shin
# acc_climbingup_data_5 - thigh
# acc_climbingup_data_5 - upperarm
# acc_climbingup_data_5 - waist
# acc_climbingdown_data_5 - chest
# acc_climbingdown_data_5 - forearm
# acc_climbingdown_data_5 - head
# acc_climbingdown_data_5 - shin
# acc_climbingdown_data_5 - thigh
# acc_climbingdown_data_5 - upperarm
# acc_climbingdown_data_5 - waist
# acc_walking_data_6 - chest
# acc_walking_data_6 - forearm
# acc_walking_data_6 - head
# acc_walking_data_6 - shin
# acc_walking_data_6 - thigh
# acc_walking_data_6 - upperarm
# acc_walking_data_6 - waist
# acc_running_data_6 - chest
# acc_running_data_6 - forearm
# acc_running_data_6 - head
# acc_running_data_6 - shin
# acc_running_data_6 - thigh
# acc_running_data_6 - upperarm
# acc_running_data_6 - waist
# acc_climbingup_data_6 - chest
# acc_climbingup_data_6 - forearm
# acc_climbingup_data_6 - head
# acc_climbingup_data_6 - shin
# acc_climbingup_data_6 - thigh
# acc_climbingup_data_6 - upperarm
# acc_climbingup_data_6 - waist
# acc_climbingdown_data_6 - chest
# acc_climbingdown_data_6 - forearm
# acc_climbingdown_data_6 - head
# acc_climbingdown_data_6 - shin
# acc_climbingdown_data_6 - thigh
# acc_climbingdown_data_6 - upperarm
# acc_climbingdown_data_6 - waist
# acc_walking_data_7 - chest
# acc_walking_data_7 - forearm
# acc_walking_data_7 - head
# acc_walking_data_7 - shin
# acc_walking_data_7 - thigh
# acc_walking_data_7 - upperarm
# acc_walking_data_7 - waist
# acc_running_data_7 - chest
# acc_running_data_7 - forearm
# acc_running_data_7 - head
# acc_running_data_7 - shin
# acc_running_data_7 - thigh
# acc_running_data_7 - upperarm
# acc_running_data_7 - waist
# acc_climbingup_data_7 - chest
# acc_climbingup_data_7 - forearm
# acc_climbingup_data_7 - head
# acc_climbingup_data_7 - shin
# acc_climbingup_data_7 - thigh
# acc_climbingup_data_7 - upperarm
# acc_climbingup_data_7 - waist
# acc_climbingdown_data_7 - chest
# acc_climbingdown_data_7 - forearm
# acc_climbingdown_data_7 - head
# acc_climbingdown_data_7 - shin
# acc_climbingdown_data_7 - thigh
# acc_climbingdown_data_7 - upperarm
# acc_climbingdown_data_7 - waist
# acc_walking_data_8 - chest
# acc_walking_data_8 - forearm
# acc_walking_data_8 - head
# acc_walking_data_8 - shin
# acc_walking_data_8 - thigh
# acc_walking_data_8 - upperarm
# acc_walking_data_8 - waist
# acc_running_data_8 - chest
# acc_running_data_8 - forearm
# acc_running_data_8 - head
# acc_running_data_8 - shin
# acc_running_data_8 - thigh
# acc_running_data_8 - upperarm
# acc_running_data_8 - waist
# acc_climbingup_data_8 - chest
# acc_climbingup_data_8 - forearm
# acc_climbingup_data_8 - head
# acc_climbingup_data_8 - shin
# acc_climbingup_data_8 - thigh
# acc_climbingup_data_8 - upperarm
# acc_climbingup_data_8 - waist
# acc_climbingdown_data_8 - chest
# acc_climbingdown_data_8 - forearm
# acc_climbingdown_data_8 - head
# acc_climbingdown_data_8 - shin
# acc_climbingdown_data_8 - thigh
# acc_climbingdown_data_8 - upperarm
# acc_climbingdown_data_8 - waist
# acc_walking_data_9 - chest
# acc_walking_data_9 - forearm
# acc_walking_data_9 - head
# acc_walking_data_9 - shin
# acc_walking_data_9 - thigh
# acc_walking_data_9 - upperarm
# acc_walking_data_9 - waist
# acc_running_data_9 - chest
# acc_running_data_9 - forearm
# acc_running_data_9 - head
# acc_running_data_9 - shin
# acc_running_data_9 - thigh
# acc_running_data_9 - upperarm
# acc_running_data_9 - waist
# acc_climbingup_data_9 - chest
# acc_climbingup_data_9 - forearm
# acc_climbingup_data_9 - head
# acc_climbingup_data_9 - shin
# acc_climbingup_data_9 - thigh
# acc_climbingup_data_9 - upperarm
# acc_climbingup_data_9 - waist
# acc_climbingdown_data_9 - chest
# acc_climbingdown_data_9 - forearm
# acc_climbingdown_data_9 - head
# acc_climbingdown_data_9 - shin
# acc_climbingdown_data_9 - thigh
# acc_climbingdown_data_9 - upperarm
# acc_climbingdown_data_9 - waist
# acc_walking_data_10 - chest
# acc_walking_data_10 - forearm
# acc_walking_data_10 - head
# acc_walking_data_10 - shin
# acc_walking_data_10 - thigh
# acc_walking_data_10 - upperarm
# acc_walking_data_10 - waist
# acc_running_data_10 - chest
# acc_running_data_10 - forearm
# acc_running_data_10 - head
# acc_running_data_10 - shin
# acc_running_data_10 - thigh
# acc_running_data_10 - upperarm
# acc_running_data_10 - waist
# acc_climbingup_data_10 - chest
# acc_climbingup_data_10 - forearm
# acc_climbingup_data_10 - head
# acc_climbingup_data_10 - shin
# acc_climbingup_data_10 - thigh
# acc_climbingup_data_10 - upperarm
# acc_climbingup_data_10 - waist
# acc_climbingdown_data_10 - chest
# acc_climbingdown_data_10 - forearm
# acc_climbingdown_data_10 - head
# acc_climbingdown_data_10 - shin
# acc_climbingdown_data_10 - thigh
# acc_climbingdown_data_10 - upperarm
# acc_climbingdown_data_10 - waist
# acc_walking_data_11 - chest
# acc_walking_data_11 - forearm
# acc_walking_data_11 - head
# acc_walking_data_11 - shin
# acc_walking_data_11 - thigh
# acc_walking_data_11 - upperarm
# acc_walking_data_11 - waist
# acc_running_data_11 - chest
# acc_running_data_11 - forearm
# acc_running_data_11 - head
# acc_running_data_11 - shin
# acc_running_data_11 - thigh
# acc_running_data_11 - upperarm
# acc_running_data_11 - waist
# acc_climbingup_data_11 - chest
# acc_climbingup_data_11 - forearm
# acc_climbingup_data_11 - head
# acc_climbingup_data_11 - shin
# acc_climbingup_data_11 - thigh
# acc_climbingup_data_11 - upperarm
# acc_climbingup_data_11 - waist
# acc_climbingdown_data_11 - chest
# acc_climbingdown_data_11 - forearm
# acc_climbingdown_data_11 - head
# acc_climbingdown_data_11 - shin
# acc_climbingdown_data_11 - thigh
# acc_climbingdown_data_11 - upperarm
# acc_climbingdown_data_11 - waist
# acc_walking_data_12 - chest
# acc_walking_data_12 - forearm
# acc_walking_data_12 - head
# acc_walking_data_12 - shin
# acc_walking_data_12 - thigh
# acc_walking_data_12 - upperarm
# acc_walking_data_12 - waist
# acc_running_data_12 - chest
# acc_running_data_12 - forearm
# acc_running_data_12 - head
# acc_running_data_12 - shin
# acc_running_data_12 - thigh
# acc_running_data_12 - upperarm
# acc_running_data_12 - waist
# acc_climbingup_data_12 - chest
# acc_climbingup_data_12 - forearm
# acc_climbingup_data_12 - head
# acc_climbingup_data_12 - shin
# acc_climbingup_data_12 - thigh
# acc_climbingup_data_12 - upperarm
# acc_climbingup_data_12 - waist
# acc_climbingdown_data_12 - chest
# acc_climbingdown_data_12 - forearm
# acc_climbingdown_data_12 - head
# acc_climbingdown_data_12 - shin
# acc_climbingdown_data_12 - thigh
# acc_climbingdown_data_12 - upperarm
# acc_climbingdown_data_12 - waist
# acc_walking_data_13 - chest
# acc_walking_data_13 - forearm
# acc_walking_data_13 - head
# acc_walking_data_13 - shin
# acc_walking_data_13 - thigh
# acc_walking_data_13 - upperarm
# acc_walking_data_13 - waist
# acc_running_data_13 - chest
# acc_running_data_13 - forearm
# acc_running_data_13 - head
# acc_running_data_13 - shin
# acc_running_data_13 - thigh
# acc_running_data_13 - upperarm
# acc_running_data_13 - waist
# acc_climbingup_data_13 - chest
# acc_climbingup_data_13 - forearm
# acc_climbingup_data_13 - head
# acc_climbingup_data_13 - shin
# acc_climbingup_data_13 - thigh
# acc_climbingup_data_13 - upperarm
# acc_climbingup_data_13 - waist
# acc_climbingdown_data_13 - chest
# acc_climbingdown_data_13 - forearm
# acc_climbingdown_data_13 - head
# acc_climbingdown_data_13 - shin
# acc_climbingdown_data_13 - thigh
# acc_climbingdown_data_13 - upperarm
# acc_climbingdown_data_13 - waist
# acc_walking_data_14 - chest
# acc_walking_data_14 - forearm
# acc_walking_data_14 - head
# acc_walking_data_14 - shin
# acc_walking_data_14 - thigh
# acc_walking_data_14 - upperarm
# acc_walking_data_14 - waist
# acc_running_data_14 - chest
# acc_running_data_14 - forearm
# acc_running_data_14 - head
# acc_running_data_14 - shin
# acc_running_data_14 - thigh
# acc_running_data_14 - upperarm
# acc_running_data_14 - waist
# acc_climbingup_data_14 - chest
# acc_climbingup_data_14 - forearm
# acc_climbingup_data_14 - head
# acc_climbingup_data_14 - shin
# acc_climbingup_data_14 - thigh
# acc_climbingup_data_14 - upperarm
# acc_climbingup_data_14 - waist
# acc_climbingdown_data_14 - chest
# acc_climbingdown_data_14 - forearm
# acc_climbingdown_data_14 - head
# acc_climbingdown_data_14 - shin
# acc_climbingdown_data_14 - thigh
# acc_climbingdown_data_14 - upperarm
# acc_climbingdown_data_14 - waist
# acc_walking_data_15 - chest
# acc_walking_data_15 - forearm
# acc_walking_data_15 - head
# acc_walking_data_15 - shin
# acc_walking_data_15 - thigh
# acc_walking_data_15 - upperarm
# acc_walking_data_15 - waist
# acc_running_data_15 - chest
# acc_running_data_15 - forearm
# acc_running_data_15 - head
# acc_running_data_15 - shin
# acc_running_data_15 - thigh
# acc_running_data_15 - upperarm
# acc_running_data_15 - waist
# acc_climbingup_data_15 - chest
# acc_climbingup_data_15 - forearm
# acc_climbingup_data_15 - head
# acc_climbingup_data_15 - shin
# acc_climbingup_data_15 - thigh
# acc_climbingup_data_15 - upperarm
# acc_climbingup_data_15 - waist
# acc_climbingdown_data_15 - chest
# acc_climbingdown_data_15 - forearm
# acc_climbingdown_data_15 - head
# acc_climbingdown_data_15 - shin
# acc_climbingdown_data_15 - thigh
# acc_climbingdown_data_15 - upperarm
# acc_climbingdown_data_15 - waist

# %%
final_table
# Out:
#             Method Subject Accelerometer Axis  Average Degree  \
# 0        NaturalVG       1                  X       11.451172
# 1        NaturalVG       1                  Y       11.986328
# 2        NaturalVG       1                  Z        8.570312
# 3     HorizontalVG       1                  X        3.958984
# 4     HorizontalVG       1                  Y        3.951172
# ...            ...     ...                ...             ...
# 2425     NaturalVG      15                  Y        9.677734
# 2426     NaturalVG      15                  Z        8.652344
# 2427  HorizontalVG      15                  X        3.917969
# 2428  HorizontalVG      15                  Y        3.933594
# 2429  HorizontalVG      15                  Z        3.962891
#
#      Network Diameter  Average Path Length      Activity Sensor
# 0                  10             4.441492       walking  chest
# 1                   9             4.241050       walking  chest
# 2                  10             4.897722       walking  chest
# 3                  26            11.578024       walking  chest
# 4                  22            10.666252       walking  chest
# ...               ...                  ...           ...    ...
# 2425               14             5.287115  climbingdown  waist
# 2426               10             4.865105  climbingdown  waist
# 2427               40            16.785202  climbingdown  waist
# 2428               31            12.079689  climbingdown  waist
# 2429               29            11.314474  climbingdown  waist
#
# [2430 rows x 8 columns]

# %%
def scatterplot(x,y,colors, title,data):
  plt.title(title)
  plt.scatter(data[x], data[y], c = colors)
  plt.xlabel(x)
  plt.ylabel(y)
  plt.show()

# %%
scatter_plot_1 = final_table[(final_table['Activity'] == 'walking') | (final_table['Activity'] == 'running')]
activities = ['walking', 'running' ]
colors = dict(zip(activities, ["orange", "#68228B"]))
axis = list("XYZ")
methods = ["NaturalVG", "HorizontalVG"]
sensors = ["chest","forearm","head","shin","thigh","upperarm","waist"]
for sensor in sensors:
  for method in methods:
    for ax in axis:
      results_scatter1 = scatter_plot_1[(scatter_plot_1['Accelerometer Axis'] == ax) & (scatter_plot_1['Method'] == method) & (scatter_plot_1['Sensor'] == sensor)]
      title =  str(method)+ ' scatter plot b/w Average Degree & Network Diameter for activity walking and running for body part '+str(sensor)+': '+str(ax)
      scatterplot('Average Degree', 'Network Diameter', results_scatter1["Activity"].map(colors), title, results_scatter1)

# %%
scatter_plot_2 = final_table[(final_table['Activity'] == 'climbingup') | (final_table['Activity'] == 'climbingdown')]
activities = ['climbingup','climbingdown' ]
colors = dict(zip(activities, ["#CD1076", "#00BFFF"]))
axis = list("XYZ")
methods = ["NaturalVG", "HorizontalVG"]
sensors = ["chest","forearm","head","shin","thigh","upperarm","waist"]
for sensor in sensors:
  for method in methods:
    for ax in axis:
      results_scatter = scatter_plot_2[(scatter_plot_2['Accelerometer Axis'] == ax) & (scatter_plot_2['Method'] == method) & (scatter_plot_2['Sensor'] == sensor)]
      title =  str(method)+' scatter plot b/w Average Degree & Network diameter for activity climbingup and climbingdown for body part '+str(sensor)+': '+ str(ax)
      scatterplot('Average Degree', 'Network Diameter', results_scatter["Activity"].map(colors), title, results_scatter)
